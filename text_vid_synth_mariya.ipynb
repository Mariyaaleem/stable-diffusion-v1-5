# %% [markdown]
# <a href="https://colab.research.google.com/github/Mariyaaleem/stable-diffusion-v1-5/blob/main/text_vid_synth_mariya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Steps for Text-to-Video Generation**
#
# **Clone Model Repository**: Clone the Stable Diffusion v1.5
# model repository from GitHub.
#
# **Set up Virtual Environment**: Create a virtual environment with Python 3.9 to manage dependencies.
#
# **Activate Virtual Environment**: Activate the virtual environment for isolated package installation.
#
# **Install Required Libraries**: Install the diffusers, torch, and imageio packages.
#
# **Import Necessary Libraries**: Import essential libraries for text-to-video processing.
#
# **Initialize Model Pipeline**: Set up the TextToVideoZeroPipeline with the model and enable GPU (CUDA) support.
#
# **Define Video Prompt**: Define the descriptive text prompt for video content generation.
#
# **Generate Video Frames**: Generate video frames based on the specified text prompt.
#
# **Save Video Output**: Save the generated frames as an mp4 file with a defined frame rate.
#
# **Download Video File**: Optionally, download the mp4 video file to your local machine from Colab.

# %% [markdown]
# **Clone Model**

# %%
# !git clone https://github.com/Mariyaaleem/stable-diffusion-v1-5.git
# Out:
# Cloning into 'stable-diffusion-v1-5'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 26 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 4.25 MiB | 18.38 MiB/s, done.

# %% [markdown]
# **Set up Virtual Environment**

# %%
# !virtualenv --system-site-packages -p python3.9 venv
# !source venv/bin/activate
# !pip install diffusers torch imageio
# Out:
# /bin/bash: line 1: virtualenv: command not found
# /bin/bash: line 1: venv/bin/activate: No such file or directory
# ...

# %%
import torch
import imageio
from diffusers import TextToVideoZeroPipeline

# load stable diffusion model weights
model_id = "runwayml/stable-diffusion-v1-5"

# create a TextToVideoZero pipeline
pipe = TextToVideoZeroPipeline.from_pretrained(model_id, torch_dtype=torch.float16).to("cuda")

# define the text prompt
prompt = "A panda is playing guitar on times square"

# generate the video using our pipeline
result = pipe(prompt=prompt).images
result = [(r * 255).astype("uint8") for r in result]

# save the resulting image
imageio.mimsave("video.mp4", result, fps=4)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# ...

# %%
# define the text prompt
prompt = "A cat is dancing on times square"

# generate the video using our pipeline
result = pipe(prompt=prompt).images
result = [(r * 255).astype("uint8") for r in result]

# save the resulting image
imageio.mimsave("video1.mp4", result, fps=4)
# Out:
# ...
#   0%|          | 0/48 [00:00<?, ?it/s]

# %%
from google.colab import files
files.download("video1.mp4")
